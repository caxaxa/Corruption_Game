# %%
import numpy as np
import matplotlib.pyplot as plt 



# Indiference Curves
n = 100
x = np.arange(0.0000001, 1,1/n )
beta = []
alpha = []
b = 4
a = 6
f = 10
N = 0.5
c = 2
gamma = 0.9
alphaIE = np.asarray(alphaIE)  

for i in x:
    alphaIE.append((-(b/(gamma**2)) + a)/ (i*(a+f))) #

alphaIB = []

for i in x:
    alphaIB.append((-(c/(gamma**2)) + b)/ (i*(b+f)))  #
    
alphaIB = np.asarray(alphaIB)   

#Ploting Indiference curves

fig, ax = plt.subplots(figsize = (5,4))

ax.plot(x, alphaIE, linewidth=2)
ax.plot(x, alphaIB,'--', linewidth=2)

fig.add_subplot(ax)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

fig.text(0.92, 0.05, '$𝛽$')
fig.text(0.11, 0.9, '$𝛼$')

ax.fill_between(x, alphaIE, facecolor='salmon', alpha=0.1)

plt.ylim([0, 1])
plt.xlim([0, 1])
plt.xticks(np.arange(0,1.1,1))
plt.yticks(np.arange(0,1.1,1))
#plt.title('Indiference curves')
plt.legend(('IC Payer', 'IC Receiver', 'Corruption Zone' ),
           loc='best', shadow=False)

# fig.text(0.18, 0.2, 'Corruption')
# fig.text(0.5, 0.4, 'No Corruption')
plt.show()

fig.savefig('fig1.pdf')

# %% [markdown]
# $\beta$

# %%
R = []
for i in x:
    R.append(0.5*i + 0.5) #
    
R = np.asarray(R)  
    
P = [0.7]*n

P = np.asarray(P)  
    
fig, ax = plt.subplots(figsize = (5,4))

ax.plot(x, alphaIE, linewidth=2)
ax.plot(x, alphaIB,'--', linewidth=2)
ax.plot(x,R,'-.',linewidth=.5 )
ax.plot(P, x,linewidth=.5 )

fig.add_subplot(ax)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

fig.text(0.92, 0.05, '$𝛽$')
fig.text(0.1, 0.9, '$𝛼$')
fig.text(0.66, 0.08, '$P*$')
fig.text(0, 0.485, '$(1 + R*)$')

ax.fill_between(x[0:71], alphaIE[0:71], facecolor='salmon', alpha=0.1)
ax.fill_between(x[70:100], alphaIE[70:100], facecolor='green', alpha=0.1)
ax.fill_between( x, alphaIE , R ,facecolor='white', alpha=1,label='_nolegend_')
ax.fill_between( x, alphaIE , R ,facecolor='yellow', alpha=.1)
ax.fill_between( x[14:100], alphaIE[14:100] , R[14:100] ,facecolor='white', alpha=1)

plt.ylim([0, 1])
plt.xlim([0, 1])
plt.xticks(np.arange(0,1.1,1))
plt.yticks(np.arange(0,1.1,1))
#plt.title('Indiference curves')
plt.legend(('IC Payer', 'IC Receiver','Self-Reporting Bonus','Plea Agreement', 'Corruption Zone','Plea Bragaining','Self-Reporting'),
           loc='upper right', shadow=False)

plt.show()

fig.savefig('fig2.pdf')

# %%
P = []
for i in x:
    P.append(gamma*(i*(a+f)+)) #
# Out:
#   File "<ipython-input-283-cea8846f7bf1>", line 3
#     P.append(gamma*(i*(a+f)+)) #
#                             ^
# SyntaxError: invalid syntax

# %%
P
# Out:
# [5.4000014400000005,
#  5.544001440000001,
#  5.688001440000001,
#  5.83200144,
#  5.97600144,
#  6.12000144,
#  6.26400144,
#  6.4080014400000005,
#  6.552001440000001,
#  6.696001440000001,
#  6.840001440000001,
#  6.98400144,
#  7.12800144,
#  7.2720014399999995,
#  7.41600144,
#  7.56000144,
#  7.70400144,
#  7.84800144,
#  7.99200144,
#  8.136001440000001,
#  8.280001440000001,
#  8.424001440000001,
#  8.568001440000002,
#  8.712001440000002,
#  8.856001440000002,
#  9.000001440000002,
#  9.144001440000002,
#  9.288001440000002,
#  9.432001440000002,
#  9.57600144,
#  9.72000144,
#  9.864001440000001,
#  10.008001440000001,
#  10.152001440000001,
#  10.296001440000001,
#  10.440001440000001,
#  10.58400144,
#  10.72800144,
#  10.87200144,
#  11.01600144,
#  11.16000144,
#  11.30400144,
#  11.44800144,
#  11.59200144,
#  11.73600144,
#  11.880001440000001,
#  12.024001440000001,
#  12.168001440000001,
#  12.312001440000001,
#  12.456001440000001,
#  12.60000144,
#  12.74400144,
#  12.88800144,
#  13.03200144,
#  13.17600144,
#  13.32000144,
#  13.46400144,
#  13.60800144,
#  13.752001439999999,
#  13.89600144,
#  14.04000144,
#  14.18400144,
#  14.32800144,
#  14.47200144,
#  14.61600144,
#  14.76000144,
#  14.90400144,
#  15.04800144,
#  15.19200144,
#  15.33600144,
#  15.48000144,
#  15.624001439999997,
#  15.76800144,
#  15.912001439999997,
#  16.056001440000003,
#  16.200001439999998,
#  16.344001440000003,
#  16.488001439999998,
#  16.632001440000003,
#  16.776001439999998,
#  16.920001440000004,
#  17.06400144,
#  17.208001440000004,
#  17.35200144,
#  17.49600144,
#  17.64000144,
#  17.78400144,
#  17.92800144,
#  18.07200144,
#  18.21600144,
#  18.36000144,
#  18.50400144,
#  18.64800144,
#  18.79200144,
#  18.936001440000002,
#  19.08000144,
#  19.22400144,
#  19.36800144,
#  19.51200144,
#  19.65600144]

# %%
P - 0.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-f51cb18ece69> in <module>
# ----> 1 P - 0.5
#
# TypeError: unsupported operand type(s) for -: 'list' and 'float'
